# %%
from vnstock import Vnstock
stock = Vnstock().stock(symbol='VCI', source='VCI')
stock.quote.history(start='2020-01-01', end='2024-05-25')
# Out:
# <!DOCTYPE html>
# <html lang="vi">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Vnstock – Còn <span id="starsLeft">160</span> ⭐ nữa!</title>
#   <style>
#     /* Isolate ad container with theme-adaptive styling */
#     #vnstock-ad-container {
#       /* Use CSS variables for theming */
#       --vnstock-primary: #4CAF50;
#       --vnstock-hover: #8C52FF;
#       /* Theme-adaptive colors that inherit from parent */
#       --vnstock-bg: inherit;
#       --vnstock-border: rgba(125,125,125,0.3);
#       --vnstock-text: inherit;
#       --vnstock-secondary-text: inherit;
#
#       /* Isolate container styles */
#       display: flex;
#       justify-content: center;
#       align-items: center;
#       padding: 16px;
#       box-sizing: border-box;
#       width: 100%;
#       max-width: 400px;
#       margin: 0 auto;
#     }
#
#     /* Theme detection and adaptation */
#     @media (prefers-color-scheme: dark) {
#       #vnstock-ad-container {
#         --vnstock-border: rgba(125,125,125,0.3);
#       }
#     }
#
#     /* Ad content styling */
#     #vnstock-ad-container .vnstock-ad {
#       width: 100%;
#       color: var(--vnstock-text);
#       background-color: var(--vnstock-bg);
#       border: 1px solid var(--vnstock-border);
#       border-radius: 8px;
#       box-shadow: 0 2px 8px rgba(0,0,0,0.08);
#       padding: 16px;
#       text-align: center;
#       font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', system-ui, sans-serif;
#     }
#
#     #vnstock-ad-container .vnstock-ad h1 {
#       font-size: 18px;
#       margin-top: 0;
#       margin-bottom: 16px;
#       line-height: 1.3;
#     }
#
#     #vnstock-ad-container .vnstock-progress {
#       background: rgba(125,125,125,0.2);
#       border-radius: 10px;
#       overflow: hidden;
#       height: 10px;
#       margin-bottom: 8px;
#     }
#
#     #vnstock-ad-container .vnstock-progress .vnstock-fill {
#       width: 80%; /* default 80% */
#       height: 100%;
#       background: var(--vnstock-primary);
#       transition: width 1s ease-out;
#     }
#
#     #vnstock-ad-container .vnstock-progress-text {
#       font-size: 12px;
#       opacity: 0.7;
#       margin-bottom: 16px;
#     }
#
#     #vnstock-ad-container .vnstock-description {
#       font-size: 14px;
#       line-height: 1.5;
#       margin-bottom: 20px;
#       text-align: left;
#     }
#
#     #vnstock-ad-container .vnstock-btn {
#       display: inline-block;
#       padding: 8px 18px;
#       background: var(--vnstock-primary);
#       color: white;
#       text-decoration: none;
#       font-weight: bold;
#       border-radius: 20px;
#       transition: background 0.3s;
#     }
#
#     #vnstock-ad-container .vnstock-btn:hover {
#       background: var(--vnstock-hover);
#     }
#   </style>
# </head>
# <body>
#   <!-- Isolated container with theme-adaptive styling -->
#   <div id="vnstock-ad-container">
#     <div class="vnstock-ad">
#       <h1 id="vnstock-ad-title">
#         Còn <span id="vnstock-stars-left">160</span> ⭐ nữa để chạm mốc 1.000!
#       </h1>
#
#       <div class="vnstock-progress">
#         <div class="vnstock-fill"></div>
#       </div>
#       <div class="vnstock-progress-text" id="vnstock-progress-text">840 / 1000 ⭐</div>
#
#       <p class="vnstock-description">
#         Mỗi ⭐ của bạn tiếp sức cho Vnstock phát triển nhanh hơn, mạnh mẽ hơn và duy trì nguồn mở.
#       </p>
#
#       <a href="https://github.com/thinh-vu/vnstock" target="_blank" class="vnstock-btn">
#         ⭐ Thả Star Ngay!
#       </a>
#     </div>
#   </div>
#
#   <script>
#     // Use immediately invoked function to avoid global scope pollution
#     (function() {
#       // Wait for DOM to be ready
#       document.addEventListener('DOMContentLoaded', () => {
#         // Fetch star count from GitHub API
#         fetch('https://api.github.com/repos/thinh-vu/vnstock')
#           .then(res => res.json())
#           .then(data => {
#             const count = data.stargazers_count || 0;
#             const left = Math.max(1000 - count, 0);
#             const pct = Math.min((count / 1000) * 100, 100);
#
#             // Update UI elements
#             document.querySelector('#vnstock-ad-container .vnstock-fill')
#                    .style.width = pct + '%';
#             document.getElementById('vnstock-progress-text')
#                    .textContent = `${count} / 1000 ⭐`;
#             document.getElementById('vnstock-stars-left')
#                    .textContent = left;
#           })
#           .catch(() => {
#             // Keep defaults if fetch fails
#           });
#       });
#     })();
#   </script>
# </body>
# </html>
#            time   open   high    low  close   volume
# 0    2020-01-02   7.08   7.08   6.98   7.08    18320
# 1    2020-01-03   7.08   7.08   6.96   7.08     2450
# 2    2020-01-06   6.83   7.15   6.83   6.98    22760
# 3    2020-01-07   7.18   7.18   6.98   6.98    18320
# 4    2020-01-08   6.83   6.98   6.83   6.98     2640
# ...         ...    ...    ...    ...    ...      ...
# 1090 2024-05-20  37.54  38.45  37.36  38.00  9168130
# 1091 2024-05-21  38.00  38.45  37.54  38.45  5081647
# 1092 2024-05-22  38.60  39.21  37.77  37.85  8230150
# 1093 2024-05-23  37.70  37.92  36.41  37.85  6340779
# 1094 2024-05-24  37.47  37.85  35.58  36.30  9858803
#
# [1095 rows x 6 columns]

# %%
from vnstock import Quote
quote = Quote(symbol='ACB', source='VCI')
quote.history(start='2024-01-01', end='2025-03-19', interval='1D')
# Out:
#           time   open   high    low  close    volume
# 0   2024-01-02  20.12  20.79  20.12  20.54  13896933
# 1   2024-01-03  20.58  21.00  20.37  21.00   9817807
# 2   2024-01-04  21.17  21.55  21.08  21.25  23605373
# 3   2024-01-05  21.25  21.38  21.04  21.38   9282598
# 4   2024-01-08  21.59  21.63  21.17  21.29  12398885
# ..         ...    ...    ...    ...    ...       ...
# 295 2025-03-13  26.35  26.45  26.10  26.10   8885500
# 296 2025-03-14  26.20  26.20  25.90  26.00  11548600
# 297 2025-03-17  26.10  26.25  26.00  26.20   5664400
# 298 2025-03-18  26.30  26.55  26.25  26.30   6008500
# 299 2025-03-19  26.30  26.30  26.05  26.20   7913600
#
# [300 rows x 6 columns]

# %%
from vnstock import Listing
listing = Listing()
listing.all_symbols()
# Out:
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1707    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1708    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1709    AAH                           Công ty Cổ phần Hợp Nhất
# 1710    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1711    A32                                 Công ty Cổ phần 32
#
# [1712 rows x 2 columns]

# %%
stock.quote.intraday(symbol='ACB', page_size=10_000, show_log=False)
# Out:
#                           time  price  volume match_type         id
# 0    2025-05-21 09:15:00+07:00  25.75     300        Buy  299544698
# 1    2025-05-21 09:15:00+07:00  25.75     200        Buy  299544798
# 2    2025-05-21 09:15:00+07:00  25.75     300        Buy  299544799
# 3    2025-05-21 09:15:00+07:00  25.75     500        Buy  299544800
# 4    2025-05-21 09:15:00+07:00  25.75     200        Buy  299544801
# ...                        ...    ...     ...        ...        ...
# 2777 2025-05-21 10:47:41+07:00  25.70     200       Sell  299790925
# 2778 2025-05-21 10:47:41+07:00  25.70    1000       Sell  299790933
# 2779 2025-05-21 10:47:41+07:00  25.70   10000       Sell  299790934
# 2780 2025-05-21 10:47:50+07:00  25.70    1000       Sell  299791313
# 2781 2025-05-21 10:47:53+07:00  25.70     100       Sell  299791393
#
# [2782 rows x 5 columns]

# %%
from vnstock import Vnstock
company = Vnstock().stock(symbol='ACB', source='VCI').company
company.overview()
# Out:
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   symbol     id  issue_share  \
# 0    ACB  67505   4466657912
#
#                                              history  \
# 0   - Ngày 24/04/1993: Ngân hàng Thương mại Cổ ph...
#
#                                      company_profile  icb_name3  icb_name2  \
# 0  Ngân hàng Thương mại Cổ phần Á Châu (ACB) được...  Ngân hàng  Ngân hàng
#
#    icb_name4  financial_ratio_issue_share  charter_capital
# 0  Ngân hàng                   4466657912   44666579120000

# %%
from vnstock import Company
company = Company(symbol='ACB', source='VCI')
company.overview()
# Out:
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   symbol     id  issue_share  \
# 0    ACB  67505   4466657912
#
#                                              history  \
# 0   - Ngày 24/04/1993: Ngân hàng Thương mại Cổ ph...
#
#                                      company_profile  icb_name3  icb_name2  \
# 0  Ngân hàng Thương mại Cổ phần Á Châu (ACB) được...  Ngân hàng  Ngân hàng
#
#    icb_name4  financial_ratio_issue_share  charter_capital
# 0  Ngân hàng                   4466657912   44666579120000

# %%
from vnstock import Vnstock
stock = Vnstock().stock(symbol='VCI', source='VCI')
# Bảng cân đối kế toán - năm
stock.finance.balance_sheet(period='year', lang='vi', dropna=True)
# Bảng cân đối kế toán - quý
stock.finance.balance_sheet(period='quarter', lang='en', dropna=True)
# Kết quả hoạt động kinh doanh
stock.finance.income_statement(period='year', lang='vi', dropna=True)
# Lưu chuyển tiền tệ
stock.finance.cash_flow(period='year', dropna=True)
# Chỉ số tài chính
stock.finance.ratio(period='year', lang='vi', dropna=True)
# Out:
#    Meta          Chỉ tiêu cơ cấu nguồn vốn                           \
#      CP   Năm Kỳ          (Vay NH+DH)/VCSH   Nợ/VCSH TSCĐ / Vốn CSH
# 0   VCI  2024  5                  0.971382  1.054349       0.002879
# 1   VCI  2023  5                  1.218152  1.340876       0.003178
# 2   VCI  2022  5                  0.973942  1.192721       0.003617
# 3   VCI  2021  5                  0.972610  1.543047       0.002011
# 4   VCI  2020  5                  0.596293  0.853905       0.003181
# 5   VCI  2019  5                  0.358125  0.787676       0.002445
# 6   VCI  2018  5                  0.270345  0.786999       0.005003
# 7   VCI  2017  5                  0.475082  1.120296       0.008388
# 8   VCI  2016  5                  0.491563  1.436668       0.007434
# 9   VCI  2015  5                  0.550475  1.532230       0.015316
# 10  VCI  2014  5                  0.364664  2.686542       0.022791
# 11  VCI  2013  5                  1.191585  2.918571       0.020265
# 12  VCI  2011  5                  3.426721  4.235392       0.016485
#
#                        Chỉ tiêu hiệu quả hoạt động                 \
#    Vốn CSH/Vốn điều lệ           Vòng quay tài sản Vòng quay TSCĐ
# 0             1.802578                    0.168564     121.775022
# 1             1.026491                    0.156992     105.385605
# 2             0.904536                    0.204426     172.225781
# 3             0.910997                    0.296344     269.213152
# 4             0.629646                    0.221383     142.402909
# 5             0.564212                    0.224089     109.544483
# 6             0.507308                    0.282137      83.645260
# 7             0.420470                    0.323097      88.278011
# 8             0.177769                    0.320657      73.282490
# 9             0.135468                    0.267767      41.241080
# 10            0.112364                    0.251576      40.964295
# 11            0.075776                    0.180038      30.100257
# 12            0.064307                    0.221780      45.438230
#
#                                ... Chỉ tiêu thanh khoản Chỉ tiêu định giá  \
#    Số ngày thu tiền bình quân  ...    Đòn bẩy tài chính               P/B
# 0                    0.000000  ...             2.054349          2.049842
# 1                    0.000000  ...             2.340876          1.970499
# 2                    0.000000  ...             2.192721          2.866248
# 3                    0.000000  ...             2.543047          1.183493
# 4                    0.000000  ...             1.853905          2.666309
# 5                    0.000000  ...             1.787676          2.418360
# 6                    0.000000  ...             1.786999          2.666718
# 7                    0.000000  ...             2.120296          2.368686
# 8                    0.000000  ...             2.436668          5.128414
# 9                   21.294522  ...             2.532230          3.318337
# 10                  31.374424  ...             3.433360          4.077489
# 11                 149.353356  ...             3.918571          4.363627
# 12                 328.174272  ...             5.235392          4.878577
#
#                                                                      \
#    Vốn hóa (Tỷ đồng) Số CP lưu hành (Triệu CP)        P/E       P/S
# 0     26533775786000                 718099480  29.135836  7.179974
# 1     14525000000000                 437500000  29.528080  5.874715
# 2     18617620767750                 435499901  21.424727  5.898666
# 3      7742250000000                 333000000   5.165914  2.088510
# 4     12055680000000                 165600000  15.678875  6.970247
# 5      9798240000000                 164400000  14.135191  6.358594
# 6      9714793444000                 162999890  11.639758  5.333463
# 7      7152000000000                 120000000  10.917481  4.654003
# 8      6150720000000                 103200000  18.357534  6.882671
# 9      2980000000000                  50000000  12.563335  4.252882
# 10     2980000000000                  50000000  20.513135  4.832263
# 11     2374464000000                  39840000  32.901021  5.944203
# 12     2252880000000                  37800000  90.235922  4.857922
#
#
#    P/Cash Flow    EPS (VND)    BVPS (VND)  EV/EBITDA
# 0    -7.840837  1268.197706  18025.783068  18.633747
# 1    -3.334822  1124.353507  16848.524590  17.525975
# 2     4.975461  1995.357941  14914.970490  12.729467
# 3    -2.064593  4500.655782  19645.234971   5.895364
# 4   -21.093469  4643.190154  27303.662559  12.313747
# 5   -28.722550  4216.426869  24644.804444  10.220559
# 6    12.398987  5120.381537  22349.571713   7.529021
# 7    -3.614195  5459.134708  25161.626644   8.311031
# 8   -46.597333  3246.623509  11621.527734  11.306346
# 9    -7.172009  4743.963391  17960.802319   8.174017
# 10    4.521565  2905.455386  14616.838928  14.166357
# 11   28.472663  1811.493953  13658.362879  28.466190
# 12  -22.732493   660.490840  12216.677603  79.644405
#
# [13 rows x 37 columns]

# %%
from vnstock.explorer.fmarket.fund import Fund
fund = Fund()
fund.listing().head()
# Out:
# 2025-05-21 10:48:00 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 56
# 2025-05-21 10:48:00 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 56
#   short_name                                        name     fund_type  \
# 0   VCBF-MGF        QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG VCBF  Quỹ cổ phiếu
# 1     SSISCA  QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI  Quỹ cổ phiếu
# 2       MBVF               QUỸ ĐẦU TƯ GIÁ TRỊ MB CAPITAL  Quỹ cổ phiếu
# 3       DCDS         QUỸ ĐẦU TƯ CHỨNG KHOÁN NĂNG ĐỘNG DC  Quỹ cổ phiếu
# 4       BVPF     QUỸ ĐẦU TƯ CỔ PHIẾU TRIỂN VỌNG BẢO VIỆT  Quỹ cổ phiếu
#
#                                      fund_owner_name  management_fee  \
# 0  CÔNG TY TNHH QUẢN LÝ QUỸ ĐẦU TƯ CHỨNG KHOÁN VI...            1.90
# 1                       CÔNG TY TNHH QUẢN LÝ QUỸ SSI            1.75
# 2              CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ ĐẦU TƯ MB            1.50
# 3  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ DRAGON CAPITAL VIỆ...            1.95
# 4                  CÔNG TY TNHH QUẢN LÝ QUỸ BẢO VIỆT            1.50
#
#   inception_date       nav  nav_change_previous  nav_change_last_year  \
# 0     2021-10-28  12708.39                 0.00                 -5.40
# 1     2014-09-25  38560.24                -0.42                 -5.46
# 2     2014-04-24  23079.00                -0.20                  3.80
# 3     2004-05-19  80831.76                -0.21                 -0.96
# 4     2016-12-28  20382.00                -0.22                 -4.48
#
#    nav_change_inception  ...  nav_change_3m  nav_change_6m  nav_change_12m  \
# 0                 27.08  ...          -6.03           1.15            4.98
# 1                167.55  ...          -5.02           0.13            1.90
# 2                 61.54  ...           1.90           8.75           10.13
# 3                187.18  ...           1.28           4.95            2.59
# 4                103.78  ...          -4.62           0.80            1.84
#
#    nav_change_24m  nav_change_36m  nav_change_36m_annualized  nav_update_at  \
# 0           41.09           36.30                      10.88     2025-05-20
# 1           49.29           35.82                      10.74     2025-05-20
# 2           34.18           34.42                      10.36     2025-05-20
# 3           48.39           32.67                       9.88     2025-05-20
# 4           33.27           29.52                       9.00     2025-05-20
#
#   fund_id_fmarket  fund_code   vsd_fee_id
# 0              46    VCBFMGF  VCBFMGFN001
# 1              11     SSISCA   SSISCAN001
# 2              47       MBVF     MBVFN001
# 3              28     VFMVF1   VFMVF1N001
# 4              14       BVPF     BVPFN001
#
# [5 rows x 21 columns]

# %%
import vnquant.vnquant.plot as pl
pl.vnquant_candle_stick(data,
                        title=None,
                        xlab='Date', ylab='Price',
                        start_date=None, end_date=None,
                        colors=['blue', 'red'],
                        width=800, height=600,
                        show_advanced=[],
                        data_source='cafe',
                        **kargs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import vnquant.vnquant.plot as pl
#       2 pl.vnquant_candle_stick(data,
#       3                         title=None,
#       4                         xlab='Date', ylab='Price',
#    (...)
#       9                         data_source='cafe',
#      10                         **kargs)
#
# File c:\Users\ADMIN\PROJECT\stock\vnquant\vnquant\__init__.py:2
#       1 # Copyright (c) vnquant. All rights reserved.
# ----> 2 from .utils import *
#       3 from .data import *
#       4 from .plot import *
#
# File c:\Users\ADMIN\PROJECT\stock\vnquant\vnquant\utils\__init__.py:1
# ----> 1 from .utils import clean_text, convert_date, convert_text_dateformat, split_change_col, extract_number, _isOHLC, _isOHLCV, get_ind_class
#       2 from .utils import date_string_to_timestamp_utc7, datetime_to_timestamp_utc7, date_difference_description, is_directory
#       3 from .exceptions import ShortTimePeriod
#
# File c:\Users\ADMIN\PROJECT\stock\vnquant\vnquant\utils\utils.py:11
#       9 from copy import deepcopy
#      10 from typing import List
# ---> 11 from vnquant.configs import USER_AGENTS
#      12 from dateutil.relativedelta import relativedelta
#      13 from dateutil.parser import parse
#
# ModuleNotFoundError: No module named 'vnquant.configs'
